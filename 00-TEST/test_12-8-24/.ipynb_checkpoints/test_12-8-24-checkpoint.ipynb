# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as py

# %%
df=pd.read_csv('penguins_lter.csv')

# %% [markdown]
# 1. Write a Python program to view basic statistical details like percentile,
# mean, std etc. of penguin data and get observations of each species
# from penguin data.

# %%
df.head()
# Out:
#   studyName  Sample Number                              Species  Region  \
# 0   PAL0708              1  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 1   PAL0708              2  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 2   PAL0708              3  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 3   PAL0708              4  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 4   PAL0708              5  Adelie Penguin (Pygoscelis adeliae)  Anvers
#
#       Island               Stage Individual ID Clutch Completion  Date Egg  \
# 0  Torgersen  Adult, 1 Egg Stage          N1A1               Yes  11/11/07
# 1  Torgersen  Adult, 1 Egg Stage          N1A2               Yes  11/11/07
# 2  Torgersen  Adult, 1 Egg Stage          N2A1               Yes  11/16/07
# 3  Torgersen  Adult, 1 Egg Stage          N2A2               Yes  11/16/07
# 4  Torgersen  Adult, 1 Egg Stage          N3A1               Yes  11/16/07
#
#    Culmen Length (mm)  Culmen Depth (mm)  Flipper Length (mm)  Body Mass (g)  \
# 0                39.1               18.7                181.0         3750.0
# 1                39.5               17.4                186.0         3800.0
# 2                40.3               18.0                195.0         3250.0
# 3                 NaN                NaN                  NaN            NaN
# 4                36.7               19.3                193.0         3450.0
#
#       Sex  Delta 15 N (o/oo)  Delta 13 C (o/oo)  \
# 0    MALE                NaN                NaN
# 1  FEMALE            8.94956          -24.69454
# 2  FEMALE            8.36821          -25.33302
# 3     NaN                NaN                NaN
# 4  FEMALE            8.76651          -25.32426
#
#                          Comments
# 0  Not enough blood for isotopes.
# 1                             NaN
# 2                             NaN
# 3              Adult not sampled.
# 4                             NaN

# %%
df.shape
# Out:
# (344, 17)

# %%
df[["Culmen Length (mm)","Culmen Depth (mm)","Flipper Length (mm)","Body Mass (g)"]].std()
# Out:
# Culmen Length (mm)       5.459584
# Culmen Depth (mm)        1.974793
# Flipper Length (mm)     14.061714
# Body Mass (g)          801.954536
# dtype: float64

# %%
df[["Culmen Length (mm)","Culmen Depth (mm)","Flipper Length (mm)","Body Mass (g)"]].mean()
# Out:
# Culmen Length (mm)       43.921930
# Culmen Depth (mm)        17.151170
# Flipper Length (mm)     200.915205
# Body Mass (g)          4201.754386
# dtype: float64

# %%
df[["Culmen Length (mm)","Culmen Depth (mm)","Flipper Length (mm)","Body Mass (g)"]].median()
# Out:
# Culmen Length (mm)       44.45
# Culmen Depth (mm)        17.30
# Flipper Length (mm)     197.00
# Body Mass (g)          4050.00
# dtype: float64

# %%
df[["Culmen Length (mm)","Culmen Depth (mm)","Flipper Length (mm)","Body Mass (g)"]].var()
# Out:
# Culmen Length (mm)         29.807054
# Culmen Depth (mm)           3.899808
# Flipper Length (mm)       197.731792
# Body Mass (g)          643131.077327
# dtype: float64

# %% [markdown]
# 2. Write a Python program to create a plot to get a general Statistics of
# Penguin data, also create a Bar plot to get the frequency of the species
# of the Penguin data.

# %%
df["Species"].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Species'>

# %% [markdown]
# 3. Write a python program to create a graph to find relationship between
# the Culmen Length and Culmen Depth.

# %%
df[["Culmen Length (mm)","Culmen Depth (mm)"]].plot(kind='bar')
# Out:
# <Axes: >

# %%
df[["Culmen Length (mm)","Culmen Depth (mm)"]].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# 4. Write a python program to create a pairplot of the penguin data set
# and check which penguin species seems to be the most separable.
# Do write your observations.

# %% [markdown]
# 5. Write a Python program to find the correlation between variables of
# penguin data. Also create a heatmap using Seaborn to present their
# relations.
