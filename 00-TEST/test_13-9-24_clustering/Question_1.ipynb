# %% [markdown]
# # 1. You are given a dataset with two numerical features Height and Weight.Your goal is to cluster these people into 3 groups using K-Means clustering.After clustering, you will visualize the clusters and their centroids.
#
#
# Load the dataset (or generate random data for practice). <br>
#  Apply K-Means clustering with k = 3 <br>.
#  Visualize the clusters and centroid <br>s.
#  Experiment with different values of k and see how the clustering chang<br>es.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.cluster import KMeans
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("HeightWeight.csv")

# %%
df.head()
# Out:
#    Index  Height(Inches)  Weight(Pounds)
# 0      1        65.78331        112.9925
# 1      2        71.51521        136.4873
# 2      3        69.39874        153.0269
# 3      4        68.21660        142.3354
# 4      5        67.78781        144.2971

# %%
df.shape
# Out:
# (25000, 3)

# %%
df.isna().sum()
# Out:
# Index             0
# Height(Inches)    0
# Weight(Pounds)    0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Index', 'Height(Inches)', 'Weight(Pounds)'], dtype='object')

# %%
#no null values, column names are ok, shape is ok

# %%
df.describe()
# Out:
#               Index  Height(Inches)  Weight(Pounds)
# count  25000.000000    25000.000000    25000.000000
# mean   12500.500000       67.993114      127.079421
# std     7217.022701        1.901679       11.660898
# min        1.000000       60.278360       78.014760
# 25%     6250.750000       66.704397      119.308675
# 50%    12500.500000       67.995700      127.157750
# 75%    18750.250000       69.272958      134.892850
# max    25000.000000       75.152800      170.924000

# %%
#describe function also look ok , at primarty no utliers are seen so lets plot box plot of it

# %%
df['Height(Inches)'].plot(kind='box')
# Out:
# <Axes: >

# %%
df['Weight(Pounds)'].plot(kind='box')
# Out:
# <Axes: >

# %%
df.hist(figsize=(15,30))
# Out:
# array([[<Axes: title={'center': 'Index'}>,
#         <Axes: title={'center': 'Height(Inches)'}>],
#        [<Axes: title={'center': 'Weight(Pounds)'}>, <Axes: >]],
#       dtype=object)
